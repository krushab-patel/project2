# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_excel("Superstore_USA.xlsx")

# %%
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
data['Product Base Margin'].fillna(data['Product Base Margin'].mean(),inplace = True)

# %% [markdown]
# # order priority

# %%
data['Order Priority'].value_counts()
# Out:
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: Order Priority, dtype: int64

# %%
data['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
data['Order Priority'] = data['Order Priority'].replace("Critical ","Critical")

# %%
data['Order Priority'].value_counts()
# Out:
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: Order Priority, dtype: int64

# %%
plt.figure(figsize=(5,3))
df = sns.countplot(data = data, x = 'Order Priority') 
plt.title("counts of order priority")
plt.savefig("count of order priority.jpg")

# %% [markdown]
# # ship mode

# %%
data['Ship Mode'].value_counts()
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
x = data['Ship Mode'].value_counts().index
y = data['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels = x,startangle = 60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(5,4))
df = sns.countplot(data = data,x = 'Ship Mode',hue= 'Product Category')

# %% [markdown]
# # customer segment

# %%
data['Customer Segment'].value_counts()
# Out:
# Corporate         3375
# Home Office       2316
# Consumer          1894
# Small Business    1841
# Name: Customer Segment, dtype: int64

# %%
x = data['Customer Segment'].value_counts().index 
y = data['Customer Segment'].value_counts().values

# %%
plt.pie(y, labels = x , startangle = 60, autopct = "%0.2f%%") 
plt.legend(loc = 1) 
plt.show()

# %% [markdown]
# # product category

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=data, x = 'Product Category')
# Out:
# <Axes: xlabel='Product Category', ylabel='count'>

# %%
plt.figure(figsize=(6,4)) 
sns.countplot(data=data, x = 'Product Category',hue = 'Product Sub-Category')
plt.show()

# %%
plt.figure(figsize=(10,4)) 
sns.countplot(data=data[data["Product Category"]=="Office Supplies"], x = 'Product Category',hue = 'Product Sub-Category')
plt.show()

# %%
plt.figure(figsize=[6,4]) 
sns.countplot(data=data[data["Product Category"]=="Furniture"], x = 'Product Category', hue = 'Product Sub-Category')
plt.show()

# %% [markdown]
# # order date

# %%
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
data['Order Date'].dt.year
# Out:
# 0       2012
# 1       2010
# 2       2011
# 3       2011
# 4       2011
#         ...
# 9421    2013
# 9422    2013
# 9423    2013
# 9424    2010
# 9425    2013
# Name: Order Date, Length: 9426, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
data['order year'].value_counts()
# Out:
# Series([], Name: order year, dtype: int64)

# %%
df = data.groupby(['Product Category'],as_index=False)['Profit'].sum().sort_values(by="Profit", ascending = False)

# %%
sns.barplot(data=df, x = "Product Category", y= "Profit")
# Out:
# <Axes: xlabel='Product Category', ylabel='Profit'>

# %%
data['State or Province'].value_counts()[:5]
# Out:
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: State or Province, dtype: int64

# %%
df = data.groupby(['Product Category'],as_index=False)['Product Base Margin'].sum().sort_values(by="Product Base Margin", ascending = False)

# %%
sns.barplot(data=df, x = "Product Category", y= "Product Base Margin")
# Out:
# <Axes: xlabel='Product Category', ylabel='Product Base Margin'>
